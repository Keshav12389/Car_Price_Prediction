# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Keshav Meena\AppData\Local\Temp\ipykernel_18812\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Laoding the data

# %%
df = pd.read_csv('car data.csv')

# %%
df.head(300)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 295      Dealer       Manual      0
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
#
# [300 rows x 9 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (301, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
df['Age'] = 2021 - df['Year']
df.drop('Year', axis=1, inplace=True)

# %%
df.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz           3.35           5.59       27000    Petrol      Dealer
# 1      sx4           4.75           9.54       43000    Diesel      Dealer
# 2     ciaz           7.25           9.85        6900    Petrol      Dealer
# 3  wagon r           2.85           4.15        5200    Petrol      Dealer
# 4    swift           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Age
# 0       Manual      0    7
# 1       Manual      0    8
# 2       Manual      0    4
# 3       Manual      0   10
# 4       Manual      0    7

# %%
df.rename(columns = {'Selling_Price':'Selling_Price(lacs)', 'Present_Price':'Present_Price(lacs)', 'Owner':'Past_Owners'}, inplace=True)

# %%
df.head()
# Out:
#   Car_Name  Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven Fuel_Type  \
# 0     ritz                 3.35                 5.59       27000    Petrol
# 1      sx4                 4.75                 9.54       43000    Diesel
# 2     ciaz                 7.25                 9.85        6900    Petrol
# 3  wagon r                 2.85                 4.15        5200    Petrol
# 4    swift                 4.60                 6.87       42450    Diesel
#
#   Seller_Type Transmission  Past_Owners  Age
# 0      Dealer       Manual            0    7
# 1      Dealer       Manual            0    8
# 2      Dealer       Manual            0    4
# 3      Dealer       Manual            0   10
# 4      Dealer       Manual            0    7

# %%
df.columns
# Out:
# Index(['Car_Name', 'Selling_Price(lacs)', 'Present_Price(lacs)', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Past_Owners', 'Age'],
#       dtype='object')

# %% [markdown]
# # Visualizing the data

# %%
cat_cols = ['Fuel_Type', 'Seller_Type', 'Transmission', 'Past_Owners']
i = 0
while i < 4:
    fig = plt.figure(figsize=[10,4])
    
    plt.subplot(1,2,1)
    sns.countplot(x=cat_cols[i], data=df)
    i +=1
    
    plt.subplot(1,2,2)
    sns.countplot(x=cat_cols[i], data=df)
    i += 1
    
    plt.show()

# %%
df[df['Present_Price(lacs)']>df['Present_Price(lacs)'].quantile(0.99)]
# Out:
#         Car_Name  Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven  \
# 64      fortuner                 33.0                36.23        6000
# 86  land cruiser                 35.0                92.60       78000
#
#    Fuel_Type Seller_Type Transmission  Past_Owners  Age
# 64    Diesel      Dealer    Automatic            0    4
# 86    Diesel      Dealer       Manual            0   11

# %%
df[df['Selling_Price(lacs)'] > df['Selling_Price(lacs)'].quantile(0.99)]
# Out:
#         Car_Name  Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven  \
# 63      fortuner                 23.5                35.96       47000
# 64      fortuner                 33.0                36.23        6000
# 86  land cruiser                 35.0                92.60       78000
#
#    Fuel_Type Seller_Type Transmission  Past_Owners  Age
# 63    Diesel      Dealer    Automatic            0    6
# 64    Diesel      Dealer    Automatic            0    4
# 86    Diesel      Dealer       Manual            0   11

# %%
df[df['Kms_Driven'] > df['Kms_Driven'].quantile(0.99)]
df_enc = df.drop('Car_Name', axis=1, inplace=False)

# %%
df_enc = pd.get_dummies(df_enc ,columns= ['Fuel_Type','Seller_Type','Transmission'], drop_first=False)

# %%
df_enc.head()
# Out:
#    Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven  Past_Owners  Age  \
# 0                 3.35                 5.59       27000            0    7
# 1                 4.75                 9.54       43000            0    8
# 2                 7.25                 9.85        6900            0    4
# 3                 2.85                 4.15        5200            0   10
# 4                 4.60                 6.87       42450            0    7
#
#    Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0          False             False              True                True
# 1          False              True             False                True
# 2          False             False              True                True
# 3          False             False              True                True
# 4          False              True             False                True
#
#    Seller_Type_Individual  Transmission_Automatic  Transmission_Manual
# 0                   False                   False                 True
# 1                   False                   False                 True
# 2                   False                   False                 True
# 3                   False                   False                 True
# 4                   False                   False                 True

# %%
df_enc.shape
# Out:
# (301, 12)

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df_enc.corr(), annot = True, cmap='RdBu')
plt.show()

# %%
df_enc.corr()['Selling_Price(lacs)']
# Out:
# Selling_Price(lacs)       1.000000
# Present_Price(lacs)       0.878983
# Kms_Driven                0.029187
# Past_Owners              -0.088344
# Age                      -0.236141
# Fuel_Type_CNG            -0.025164
# Fuel_Type_Diesel          0.552339
# Fuel_Type_Petrol         -0.540571
# Seller_Type_Dealer        0.550724
# Seller_Type_Individual   -0.550724
# Transmission_Automatic    0.367128
# Transmission_Manual      -0.367128
# Name: Selling_Price(lacs), dtype: float64

# %%
df.pivot_table(values='Selling_Price(lacs)', index = 'Seller_Type', columns='Fuel_Type')
# Out:
# Fuel_Type    CNG     Diesel    Petrol
# Seller_Type
# Dealer       3.1  10.181525  5.252388
# Individual   NaN  16.000000  0.726857

# %%
# Creating dummies for categorical values
df.drop(labels='Car_Name', axis=1, inplace = True)

# %%
df.head()
# Out:
#    Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven Fuel_Type Seller_Type  \
# 0                 3.35                 5.59       27000    Petrol      Dealer
# 1                 4.75                 9.54       43000    Diesel      Dealer
# 2                 7.25                 9.85        6900    Petrol      Dealer
# 3                 2.85                 4.15        5200    Petrol      Dealer
# 4                 4.60                 6.87       42450    Diesel      Dealer
#
#   Transmission  Past_Owners  Age
# 0       Manual            0    7
# 1       Manual            0    8
# 2       Manual            0    4
# 3       Manual            0   10
# 4       Manual            0    7

# %%
df = pd.get_dummies(data=df, drop_first=True)

# %%
df.head()
# Out:
#    Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven  Past_Owners  Age  \
# 0                 3.35                 5.59       27000            0    7
# 1                 4.75                 9.54       43000            0    8
# 2                 7.25                 9.85        6900            0    4
# 3                 2.85                 4.15        5200            0   10
# 4                 4.60                 6.87       42450            0    7
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0             False              True                   False
# 1              True             False                   False
# 2             False              True                   False
# 3             False              True                   False
# 4              True             False                   False
#
#    Transmission_Manual
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True

# %% [markdown]
# # Train - Test - Split

# %%
# Train Test Split
X = df.iloc[:,1:].values
y = df.iloc[:,:1].values

# %%
print(X)
# Out:
# [[5.59 27000 0 ... True False True]
#  [9.54 43000 0 ... False False True]
#  [9.85 6900 0 ... True False True]
#  ...
#  [11.0 87934 0 ... True False True]
#  [12.5 9000 0 ... False False True]
#  [5.9 5464 0 ... True False True]]

# %%
# print(y)

# %%
print(X.shape, y.shape)
# Out:
# (301, 8) (301, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)
#
# NameError: name 'X' is not defined

# %% [markdown]
# # Scaling the data for better training

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (301, 8) (240, 8) (61, 8)

# %%
print(y.shape, y_train.shape, y_test.shape)
# Out:
# (301, 1) (240, 1) (61, 1)

# %% [markdown]
# # Building Artifical Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(30, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1)) # O/P

model.compile(optimizer='rmsprop', loss='mse')

# %%
model.fit(X_train, y_train, epochs=100, validation_data=(X_test,y_test))
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 29.2846 - val_loss: 30.4479
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.4147 - val_loss: 27.9669
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.2396 - val_loss: 25.4151
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.2639 - val_loss: 22.6734
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.5829 - val_loss: 19.7455
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.9622 - val_loss: 17.3432
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.7250 - val_loss: 14.9142
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.3946 - val_loss: 12.5876
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.5384 - val_loss: 10.5187
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.8885 - val_loss: 8.5999
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.9564 - val_loss: 6.7867
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3679 - val_loss: 5.4869
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6930 - val_loss: 4.6114
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3980 - val_loss: 3.9061
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7527 - val_loss: 3.4496
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3985 - val_loss: 3.1096
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5830 - val_loss: 2.8936
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4448 - val_loss: 2.6642
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4645 - val_loss: 2.4230
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4203 - val_loss: 2.3018
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2856 - val_loss: 2.0910
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7236 - val_loss: 1.9322
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4413 - val_loss: 1.8162
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8420 - val_loss: 1.6739
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9107 - val_loss: 1.6002
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9621 - val_loss: 1.5192
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1947 - val_loss: 1.5121
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8328 - val_loss: 1.4286
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7036 - val_loss: 1.3779
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6003 - val_loss: 1.4036
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5527 - val_loss: 1.4109
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6963 - val_loss: 1.3785
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3973 - val_loss: 1.3850
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6663 - val_loss: 1.2324
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0997 - val_loss: 1.3594
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1782 - val_loss: 1.2027
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2209 - val_loss: 1.2432
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2332 - val_loss: 1.2249
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1057 - val_loss: 1.2129
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4165 - val_loss: 1.2768
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1347 - val_loss: 1.1787
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4043 - val_loss: 1.1628
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2334 - val_loss: 1.2181
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3078 - val_loss: 1.2406
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1353 - val_loss: 1.1295
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9330 - val_loss: 1.1681
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1832 - val_loss: 1.1461
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9499 - val_loss: 1.1717
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9310 - val_loss: 1.2016
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8616 - val_loss: 1.1459
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9080 - val_loss: 1.1349
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0991 - val_loss: 1.1405
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1054 - val_loss: 1.0896
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1819 - val_loss: 1.1414
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6808 - val_loss: 1.1561
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9759 - val_loss: 1.0968
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9191 - val_loss: 1.0350
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0016 - val_loss: 1.0938
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8862 - val_loss: 1.1577
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9547 - val_loss: 1.1597
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8166 - val_loss: 1.1158
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6398 - val_loss: 1.2593
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0215 - val_loss: 1.1392
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8322 - val_loss: 1.1720
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8942 - val_loss: 1.2127
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0356 - val_loss: 1.0742
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8181 - val_loss: 1.0720
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8274 - val_loss: 0.9725
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8210 - val_loss: 1.1168
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6815 - val_loss: 1.1395
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8124 - val_loss: 1.0610
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7147 - val_loss: 1.0691
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7400 - val_loss: 0.9629
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6313 - val_loss: 1.0936
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7625 - val_loss: 1.0318
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6818 - val_loss: 1.1042
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7912 - val_loss: 0.9829
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7924 - val_loss: 1.0422
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7359 - val_loss: 0.9714
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7345 - val_loss: 1.0659
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5946 - val_loss: 1.1043
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8490 - val_loss: 0.9992
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7935 - val_loss: 1.0408
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6767 - val_loss: 1.0300
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5785 - val_loss: 1.0270
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7822 - val_loss: 0.9605
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8384 - val_loss: 1.0667
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6181 - val_loss: 1.0597
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8757 - val_loss: 1.0611
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6769 - val_loss: 0.9413
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7873 - val_loss: 0.9428
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8588 - val_loss: 0.9558
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5700 - val_loss: 0.9584
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7495 - val_loss: 0.9362
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8250 - val_loss: 0.9281
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5413 - val_loss: 1.0420
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8001 - val_loss: 1.0480
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6937 - val_loss: 0.9903
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5700 - val_loss: 1.0970
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7805 - val_loss: 0.9228

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 30)             │           270 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           310 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,184 (4.63 KB)
#  Trainable params: 591 (2.31 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 593 (2.32 KB)

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
loss_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Model Evaluation

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9029
# 0.92279052734375

# %% [markdown]
# ## model.predict() on X_test

# %%
train_pred = model.predict(X_train)
# print(pred_train)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## model.predict()  on X_train

# %%
test_pred = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# - R Squared : R-squared measures the strength of the relationship between your model and the dependent variable on a convenient 0 – 100% scale.

# %%
r2_train = r2_score(y_train, train_pred)
print("R Squared value of train dataL: ",r2_train)
# Out:
# R Squared value of train dataL:  0.9768208949232429

# %%
r2_test = r2_score(y_test, test_pred)
print("R Squared value of test data:", r2_test)
# Out:
# R Squared value of test data: 0.9574636858681476

# %%
diff_r2_scores = r2_train - r2_test

# %%
print("Difference between two scores: ", round(diff_r2_scores, 2))
# Out:
# Difference between two scores:  0.02
